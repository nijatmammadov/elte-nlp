# %%
# !pip install "ultralytics<=8.3.40"
# Out:
# Collecting ultralytics<=8.3.40
#   Downloading ultralytics-8.3.40-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics<=8.3.40) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics<=8.3.40) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics<=8.3.40) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics<=8.3.40) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics<=8.3.40) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics<=8.3.40) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics<=8.3.40) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics<=8.3.40) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics<=8.3.40) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics<=8.3.40) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics<=8.3.40) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics<=8.3.40) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics<=8.3.40) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics<=8.3.40) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics<=8.3.40)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics<=8.3.40) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics<=8.3.40) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics<=8.3.40) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics<=8.3.40) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics<=8.3.40) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics<=8.3.40) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics<=8.3.40) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics<=8.3.40) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics<=8.3.40) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics<=8.3.40) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics<=8.3.40) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics<=8.3.40) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics<=8.3.40) (2025.4.26)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics<=8.3.40) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics<=8.3.40) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics<=8.3.40) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics<=8.3.40) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics<=8.3.40) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics<=8.3.40)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics<=8.3.40)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics<=8.3.40)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics<=8.3.40)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics<=8.3.40)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics<=8.3.40)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics<=8.3.40)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics<=8.3.40)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics<=8.3.40)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics<=8.3.40) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics<=8.3.40) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics<=8.3.40) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics<=8.3.40)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics<=8.3.40) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics<=8.3.40) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics<=8.3.40) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics<=8.3.40) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics<=8.3.40) (3.0.2)
# Downloading ultralytics-8.3.40-py3-none-any.whl (898 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.5/898.5 kB 15.0 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 48.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 31.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.5 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.3 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 88.2 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.40 ultralytics-thop-2.0.14

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from ultralytics import YOLO
import os
import random
import shutil
import glob
import matplotlib.pyplot as plt
import base64
import cv2
import numpy as np
from PIL import Image
import io
import openai
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
data_folders = glob.glob("/content/drive/MyDrive/nlp_project_elte/data/*")

# %%
sections = {}
current_heading = None
current_content = []

with open(glob.glob("/content/drive/MyDrive/nlp_project_elte/data/*")[0], 'r', encoding='utf-8') as f:
    for line in f:
        if line.startswith("## "):  # Detect heading
            # Save previous section
            if current_heading:
                sections[current_heading] = ''.join(current_content).strip()
            # Start new section
            current_heading = line.strip()[3:]  # Remove '## ' prefix
            current_content = []
        else:
            current_content.append(line)

    # Save last section
    if current_heading:
        sections[current_heading] = ''.join(current_content).strip()

# %%
def convert_yolo_result_to_base64(yolo_result):
    result_image_array = yolo_result.plot(labels=False)
    result_image_pil = Image.fromarray(cv2.cvtColor(result_image_array, cv2.COLOR_BGR2RGB))

    with io.BytesIO() as buffer:
        result_image_pil.save(buffer, format="PNG")
        base64_bytes = buffer.getvalue()
        base64_str = base64.b64encode(base64_bytes).decode("utf-8")

    return base64_str  # No ...

# %%
from google.colab import userdata
api = userdata.get('OPENAI_API_KEY')
client = openai.OpenAI(api_key=api)

# %%
def describe(img_path, text):
    yolo_model = YOLO("/content/drive/MyDrive/nlp_project_elte/od/od/saved_model.pt")

    results = yolo_model.predict(source=img_path, save=False, conf=0.25)
    # Get base64-encoded string
    base64_data = convert_yolo_result_to_base64(results[0])
    system_msg = """
    You are a highly observant assistant trained in visual and technical analysis of vehicles. You will receive an image showing a detected vehicle (car, truck, or bus), sometimes accompanied by a technical description.

    Your goal is to generate a rich, accurate, and informative textual description using the following structure:

    ---

    1. **Vehicle Identification and Description**
      - If a technical description is provided, integrate it with your visual analysis. Verify details (e.g., brand, model, year, trim) and provide additional context from the image.
      - If no description is available, generate a detailed narrative based on visual clues alone.
      - Identify:
        - Make and model (e.g., Ford F-150, Toyota Prius)
        - Body type (e.g., sedan, SUV, pickup, minibus)
        - Color and paint condition
        - Visible damage, rust, or wear
        - Modifications (e.g., custom wheels, added accessories, decals)
        - License plate (blur if privacy required)

    2. **Condition Assessment**
      - Estimate the vehicle's condition (e.g., excellent, fair, poor) based on visible wear, cleanliness, or damage.
      - Note any distinguishing features (e.g., dents, broken headlights, missing parts).

    3. **(Optional) Market Price Estimation**
      - Provide an estimated price range based on the make, model, year, and condition.
      - Use a reference source like Kelley Blue Book, Edmunds, or used vehicle marketplaces.
      - Include source of estimation if applicable.

    4. **(Optional) Technical Commentary**
      - If a technical description is present, explain or correct any inconsistencies using visual evidence.
      - Add context (e.g., fuel type, engine class, emissions rating) if visible or inferred.

    5. **(Optional) Suggested Applications**
      - Recommend possible use cases (e.g., private transport, commercial delivery, off-road use).
      - If the vehicle appears damaged or old, suggest resale, repair, parts salvage, or donation.

    ---

    **Output Format Example:**

    Vehicle Summary:
    A silver 2019 Toyota Hiace minibus with commercial decals and minor front bumper damage.

    Detailed Description:
    The vehicle is a mid-sized passenger van with a high roof, silver body paint, and commercial markings on both sides. The front bumper appears slightly dented, and the paint shows signs of wear near the wheel arches. The tires are visibly used but intact. The license plate is partially visible, and the side mirrors are intact. No obvious aftermarket modifications.

    Condition Assessment:
    Good overall condition, with minor cosmetic damage. Likely used for commercial passenger transport.

    Market Price Estimation:
    Estimated value: $17,000 – $20,000
    Based on listings from [Autotrader, OLX, or local market].

    """
    # Send to OpenAI with correct MIME type
    response = client.chat.completions.create(
        model="gpt-4o",
        messages=[
            {
                "role": "system",
                "content": [
                    {"type": "text", "text": system_msg},
                ]
            },
            {
                "role": "user",
                "content": [
                    {"type": "text", "text": f"Describe this image. {text}"},
                    {
                        "type": "image_url",
                        "image_url": {
                            "url": f"data:image/png;base64,{base64_data}"
                        }
                    }
                ]
            }
        ],
        max_tokens=500
    )

    # Print the description
    return response.choices[0].message.content

# %%
data = {"images": [], "descriptions": []}

for i in data_folders[3:]:
  ims = glob.glob(f"{i}/*.jpg")
  for j in ims:
    description = ""
    if i.split("/")[-1] in sections.keys():
      print(j)
      description = describe(j,sections[i.split("/")[-1]])
    else:
      description = describe(j, "")
    data["images"].append(j)
    data["descriptions"].append(description)
# Out:
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_133308_anonimized.jpg: 480x640 2 Automobiles, 243.8ms
# Speed: 5.7ms preprocess, 243.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_133319_anonimized.jpg: 480x640 3 Automobiles, 257.8ms
# Speed: 5.7ms preprocess, 257.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_133327_anonimized.jpg: 480x640 1 Automobile, 260.4ms
# Speed: 7.2ms preprocess, 260.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_133336_anonimized.jpg: 480x640 1 Automobile, 168.8ms
# Speed: 4.4ms preprocess, 168.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_133333_anonimized.jpg: 480x640 3 Automobiles, 173.7ms
# Speed: 10.1ms preprocess, 173.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_133442_anonimized.jpg: 480x640 1 Automobile, 166.0ms
# Speed: 5.2ms preprocess, 166.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_133314_anonimized.jpg: 480x640 2 Automobiles, 174.4ms
# Speed: 5.8ms preprocess, 174.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_133412_anonimized.jpg: 480x640 1 Automobile, 180.9ms
# Speed: 5.2ms preprocess, 180.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_133446_anonimized.jpg: 480x640 1 Automobile, 263.6ms
# Speed: 5.0ms preprocess, 263.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_133343_anonimized.jpg: 480x640 1 Automobile, 164.7ms
# Speed: 5.5ms preprocess, 164.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_133448_anonimized.jpg: 480x640 1 Automobile, 188.0ms
# Speed: 4.4ms preprocess, 188.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_133503_anonimized.jpg: 640x480 1 Automobile, 177.8ms
# Speed: 5.5ms preprocess, 177.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_133453_anonimized.jpg: 480x640 1 Automobile, 167.8ms
# Speed: 5.1ms preprocess, 167.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_133511_anonimized.jpg: 480x640 1 Automobile, 169.9ms
# Speed: 4.5ms preprocess, 169.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_133542_anonimized.jpg: 480x640 1 Automobile, 166.8ms
# Speed: 5.4ms preprocess, 166.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_133524_anonimized.jpg: 480x640 1 Automobile, 168.0ms
# Speed: 4.3ms preprocess, 168.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_133545_anonimized.jpg: 480x640 1 Automobile, 166.6ms
# Speed: 5.3ms preprocess, 166.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_133556_anonimized.jpg: 480x640 1 Automobile, 166.8ms
# Speed: 4.3ms preprocess, 166.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_133552_anonimized.jpg: 480x640 1 Automobile, 167.7ms
# Speed: 5.0ms preprocess, 167.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_133614_anonimized.jpg: 480x640 1 Automobile, 189.1ms
# Speed: 5.3ms preprocess, 189.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_133654_1_anonimized.jpg: 480x640 1 Automobile, 168.5ms
# Speed: 4.5ms preprocess, 168.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_133626_anonimized.jpg: 480x640 2 Automobiles, 168.6ms
# Speed: 4.4ms preprocess, 168.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_133654_anonimized.jpg: 480x640 1 Automobile, 162.2ms
# Speed: 4.5ms preprocess, 162.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_133629_anonimized.jpg: 480x640 1 Automobile, 255.0ms
# Speed: 6.0ms preprocess, 255.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_133658_anonimized.jpg: 480x640 1 Automobile, 268.4ms
# Speed: 6.0ms preprocess, 268.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_133712_anonimized.jpg: 480x640 1 Automobile, 171.1ms
# Speed: 4.3ms preprocess, 171.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_133717_anonimized.jpg: 480x640 1 Automobile, 171.4ms
# Speed: 5.1ms preprocess, 171.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_133721_anonimized.jpg: 480x640 1 Automobile, 166.8ms
# Speed: 4.7ms preprocess, 166.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_133723_anonimized.jpg: 480x640 1 Automobile, 190.2ms
# Speed: 5.9ms preprocess, 190.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_133727_anonimized.jpg: 480x640 1 Automobile, 168.4ms
# Speed: 4.7ms preprocess, 168.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_133759_anonimized.jpg: 640x480 1 Automobile, 276.5ms
# Speed: 7.3ms preprocess, 276.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_133706_anonimized.jpg: 480x640 1 Automobile, 265.6ms
# Speed: 6.1ms preprocess, 265.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_133900_anonimized.jpg: 480x640 1 Automobile, 172.3ms
# Speed: 5.6ms preprocess, 172.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_133921_anonimized.jpg: 480x640 1 Automobile, 170.2ms
# Speed: 4.5ms preprocess, 170.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_133953_anonimized.jpg: 480x640 1 Automobile, 262.1ms
# Speed: 6.1ms preprocess, 262.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_134014_anonimized.jpg: 480x640 1 Automobile, 275.0ms
# Speed: 6.1ms preprocess, 275.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_133937_anonimized.jpg: 640x480 1 Automobile, 172.1ms
# Speed: 4.7ms preprocess, 172.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_134028_anonimized.jpg: 480x640 1 Automobile, 173.6ms
# Speed: 5.1ms preprocess, 173.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_134025_anonimized.jpg: 480x640 1 Automobile, 170.0ms
# Speed: 4.4ms preprocess, 170.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_134017_anonimized.jpg: 480x640 1 Automobile, 189.1ms
# Speed: 6.2ms preprocess, 189.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165671/IMG_20241112_133932_anonimized.jpg: 640x480 2 Automobiles, 168.9ms
# Speed: 4.6ms preprocess, 168.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# /content/drive/MyDrive/nlp_project_elte/data/CZ LOKO/20210714_154816_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/CZ LOKO/20210714_154816_anonimized.jpg: 480x640 3 Automobiles, 252.0ms
# Speed: 5.4ms preprocess, 252.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/CZ LOKO/20210714_154803_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/CZ LOKO/20210714_154803_anonimized.jpg: 480x640 1 Automobile, 167.1ms
# Speed: 3.7ms preprocess, 167.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/CZ LOKO/1_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/CZ LOKO/1_anonimized.jpg: 480x640 2 Automobiles, 162.7ms
# Speed: 3.9ms preprocess, 162.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/CZ LOKO/20210714_154923_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/CZ LOKO/20210714_154923_anonimized.jpg: 480x640 1 Automobile, 165.6ms
# Speed: 3.7ms preprocess, 165.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/CZ LOKO/20210714_154801_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/CZ LOKO/20210714_154801_anonimized.jpg: 480x640 1 Automobile, 166.2ms
# Speed: 4.6ms preprocess, 166.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/CZ LOKO/20210714_154746_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/CZ LOKO/20210714_154746_anonimized.jpg: 480x640 1 Automobile, 172.9ms
# Speed: 3.7ms preprocess, 172.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/CZ LOKO/20210714_154835_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/CZ LOKO/20210714_154835_anonimized.jpg: 480x640 1 Automobile, 164.2ms
# Speed: 3.8ms preprocess, 164.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/CZ LOKO/20210714_154920_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/CZ LOKO/20210714_154920_anonimized.jpg: 480x640 1 Automobile, 296.6ms
# Speed: 5.5ms preprocess, 296.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/CZ LOKO/20210714_154823_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/CZ LOKO/20210714_154823_anonimized.jpg: 480x640 1 Automobile, 164.7ms
# Speed: 3.9ms preprocess, 164.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/CZ LOKO/20210714_154914_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/CZ LOKO/20210714_154914_anonimized.jpg: 480x640 1 Automobile, 161.4ms
# Speed: 4.0ms preprocess, 161.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/CZ LOKO/20210714_154930_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/CZ LOKO/20210714_154930_anonimized.jpg: 480x640 1 Automobile, 264.1ms
# Speed: 6.2ms preprocess, 264.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/CZ LOKO/20210714_154906_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/CZ LOKO/20210714_154906_anonimized.jpg: 480x640 1 Automobile, 163.5ms
# Speed: 3.8ms preprocess, 163.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/CZ LOKO/20210714_154942_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/CZ LOKO/20210714_154942_anonimized.jpg: 480x640 1 Automobile, 172.3ms
# Speed: 3.8ms preprocess, 172.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/CZ LOKO/20210714_154958_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/CZ LOKO/20210714_154958_anonimized.jpg: 480x640 1 Automobile, 167.0ms
# Speed: 3.8ms preprocess, 167.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/CZ LOKO/20210714_154934_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/CZ LOKO/20210714_154934_anonimized.jpg: 480x640 1 Automobile, 167.5ms
# Speed: 3.8ms preprocess, 167.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/CZ LOKO/20210714_154950_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/CZ LOKO/20210714_154950_anonimized.jpg: 480x640 1 Automobile, 182.7ms
# Speed: 3.9ms preprocess, 182.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/CZ LOKO/20210714_155006_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/CZ LOKO/20210714_155006_anonimized.jpg: 480x640 1 Automobile, 162.5ms
# Speed: 3.9ms preprocess, 162.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/CZ LOKO/2_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/CZ LOKO/2_anonimized.jpg: 256x640 2 Automobiles, 103.1ms
# Speed: 1.9ms preprocess, 103.1ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 640)
# /content/drive/MyDrive/nlp_project_elte/data/CZ LOKO/20210714_154953_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/CZ LOKO/20210714_154953_anonimized.jpg: 480x640 1 Automobile, 166.8ms
# Speed: 3.6ms preprocess, 166.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/162390/20240828_121502_anonimized.jpg: 480x640 2 Automobiles, 179.1ms
# Speed: 4.4ms preprocess, 179.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/162390/20240828_121510_anonimized.jpg: 480x640 2 Automobiles, 159.3ms
# Speed: 4.8ms preprocess, 159.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/162390/20240828_121519_anonimized.jpg: 480x640 1 Automobile, 261.8ms
# Speed: 5.5ms preprocess, 261.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/162390/20240828_121514_anonimized.jpg: 480x640 1 Automobile, 164.1ms
# Speed: 4.2ms preprocess, 164.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/162390/20240828_121540_anonimized.jpg: 480x640 3 Automobiles, 161.5ms
# Speed: 4.4ms preprocess, 161.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/162390/20240828_121551_anonimized.jpg: 480x640 1 Automobile, 162.0ms
# Speed: 4.2ms preprocess, 162.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/162390/20240828_121545_anonimized.jpg: 480x640 1 Automobile, 253.2ms
# Speed: 4.4ms preprocess, 253.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/162390/20240828_121552_anonimized.jpg: 480x640 3 Automobiles, 251.8ms
# Speed: 6.2ms preprocess, 251.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/162390/20240828_121556_anonimized.jpg: 480x640 2 Automobiles, 281.7ms
# Speed: 6.0ms preprocess, 281.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/162390/20240828_121615_anonimized.jpg: 480x640 1 Automobile, 170.1ms
# Speed: 4.5ms preprocess, 170.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/162390/20240828_121656_anonimized.jpg: 480x640 1 Automobile, 163.8ms
# Speed: 4.4ms preprocess, 163.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/162390/20240828_121824_anonimized.jpg: 480x640 1 Automobile, 166.2ms
# Speed: 4.5ms preprocess, 166.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/162390/20240828_121703_anonimized.jpg: 480x640 3 Automobiles, 164.7ms
# Speed: 4.7ms preprocess, 164.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/162390/20240828_121621_anonimized.jpg: 480x640 1 Automobile, 163.6ms
# Speed: 4.8ms preprocess, 163.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165720/IMG_20241118_100037_anonimized.jpg: 480x640 1 Automobile, 179.2ms
# Speed: 4.4ms preprocess, 179.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165720/IMG_20241118_100033_anonimized.jpg: 480x640 2 Automobiles, 168.1ms
# Speed: 4.2ms preprocess, 168.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165720/IMG_20241118_100943_anonimized.jpg: 480x640 3 Automobiles, 159.9ms
# Speed: 4.4ms preprocess, 159.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165720/IMG_20241118_100056_anonimized.jpg: 640x480 2 Automobiles, 166.6ms
# Speed: 4.8ms preprocess, 166.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165720/IMG_20241118_100047_anonimized.jpg: 640x480 1 Automobile, 167.7ms
# Speed: 4.4ms preprocess, 167.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165720/IMG_20241118_101004_anonimized.jpg: 480x640 2 Automobiles, 165.2ms
# Speed: 4.6ms preprocess, 165.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165720/IMG_20241118_101008_anonimized.jpg: 480x640 1 Automobile, 170.9ms
# Speed: 4.6ms preprocess, 170.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165720/IMG_20241118_100958_anonimized.jpg: 480x640 1 Automobile, 276.3ms
# Speed: 7.0ms preprocess, 276.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165720/IMG_20241118_100949_anonimized.jpg: 480x640 1 Automobile, 261.6ms
# Speed: 6.0ms preprocess, 261.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165720/IMG_20241118_101114_anonimized.jpg: 480x640 1 Automobile, 164.6ms
# Speed: 4.3ms preprocess, 164.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165720/IMG_20241118_101119_anonimized.jpg: 480x640 1 Automobile, 264.0ms
# Speed: 6.2ms preprocess, 264.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165720/IMG_20241118_101105_anonimized.jpg: 480x640 1 Automobile, 202.8ms
# Speed: 4.5ms preprocess, 202.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165720/IMG_20241118_101153_anonimized.jpg: 480x640 2 Automobiles, 255.7ms
# Speed: 4.3ms preprocess, 255.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165720/IMG_20241118_101128_anonimized.jpg: 480x640 1 Automobile, 168.7ms
# Speed: 4.6ms preprocess, 168.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165720/IMG_20241118_101137_anonimized.jpg: 480x640 1 Automobile, 172.6ms
# Speed: 6.9ms preprocess, 172.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165720/IMG_20241118_101131_anonimized.jpg: 480x640 1 Automobile, 167.0ms
# Speed: 4.8ms preprocess, 167.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165720/IMG_20241118_101227_anonimized.jpg: 480x640 1 Automobile, 261.5ms
# Speed: 6.3ms preprocess, 261.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165720/IMG_20241118_101134_anonimized.jpg: 480x640 1 Automobile, 169.7ms
# Speed: 4.4ms preprocess, 169.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165720/IMG_20241118_101223_anonimized.jpg: 480x640 1 Automobile, 164.2ms
# Speed: 4.5ms preprocess, 164.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165720/IMG_20241118_101220_anonimized.jpg: 480x640 1 Automobile, 181.9ms
# Speed: 4.5ms preprocess, 181.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165720/IMG_20241118_101207_anonimized.jpg: 480x640 2 Automobiles, 175.0ms
# Speed: 4.4ms preprocess, 175.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165720/IMG_20241118_101308_anonimized.jpg: 480x640 1 Automobile, 184.0ms
# Speed: 4.4ms preprocess, 184.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165720/IMG_20241118_101318_anonimized.jpg: 480x640 1 Automobile, 167.3ms
# Speed: 5.2ms preprocess, 167.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165720/IMG_20241118_101231_anonimized.jpg: 480x640 1 Automobile, 172.7ms
# Speed: 4.7ms preprocess, 172.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165720/IMG_20241118_101313_anonimized.jpg: 480x640 1 Automobile, 174.2ms
# Speed: 6.1ms preprocess, 174.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165720/IMG_20241118_101348_anonimized.jpg: 480x640 1 Automobile, 165.2ms
# Speed: 4.3ms preprocess, 165.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165720/IMG_20241118_101332_anonimized.jpg: 480x640 1 Automobile, 264.7ms
# Speed: 8.0ms preprocess, 264.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165720/IMG_20241118_101345_anonimized.jpg: 480x640 1 Automobile, 165.4ms
# Speed: 4.5ms preprocess, 165.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165720/IMG_20241118_101324_anonimized.jpg: 480x640 1 Automobile, 160.6ms
# Speed: 4.2ms preprocess, 160.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165720/IMG_20241118_101353_anonimized.jpg: 640x480 1 Automobile, 170.2ms
# Speed: 4.6ms preprocess, 170.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165720/IMG_20241118_101415_anonimized.jpg: 480x640 1 Automobile, 163.3ms
# Speed: 4.4ms preprocess, 163.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165720/IMG_20241118_101357_anonimized.jpg: 480x640 1 Automobile, 184.5ms
# Speed: 4.7ms preprocess, 184.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165720/IMG_20241118_101342_anonimized.jpg: 480x640 1 Automobile, 162.8ms
# Speed: 4.4ms preprocess, 162.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165484/IMG_20241002_130931_anonimized.jpg: 480x640 1 Automobile, 182.1ms
# Speed: 4.4ms preprocess, 182.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165484/IMG_20241002_130924_anonimized.jpg: 480x640 3 Automobiles, 181.7ms
# Speed: 4.5ms preprocess, 181.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165484/IMG_20241002_130941_anonimized.jpg: 480x640 1 Automobile, 251.7ms
# Speed: 5.5ms preprocess, 251.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165484/IMG_20241002_131009_anonimized.jpg: 480x640 1 Automobile, 162.7ms
# Speed: 4.3ms preprocess, 162.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165484/IMG_20241002_131000_anonimized.jpg: 480x640 1 Automobile, 165.9ms
# Speed: 4.4ms preprocess, 165.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165484/IMG_20241002_130946_anonimized.jpg: 480x640 3 Automobiles, 170.7ms
# Speed: 4.2ms preprocess, 170.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165484/IMG_20241002_130950_anonimized.jpg: 480x640 2 Automobiles, 167.9ms
# Speed: 4.6ms preprocess, 167.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165484/IMG_20241002_131011_anonimized.jpg: 480x640 2 Automobiles, 266.1ms
# Speed: 6.2ms preprocess, 266.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165484/IMG_20241002_131014_anonimized.jpg: 480x640 1 Automobile, 163.9ms
# Speed: 4.2ms preprocess, 163.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165484/IMG_20241002_131106_anonimized.jpg: 480x640 2 Automobiles, 159.3ms
# Speed: 4.4ms preprocess, 159.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165484/IMG_20241002_131111_anonimized.jpg: 480x640 1 Automobile, 162.2ms
# Speed: 4.4ms preprocess, 162.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165484/IMG_20241002_131055_anonimized.jpg: 480x640 1 Automobile, 174.1ms
# Speed: 4.5ms preprocess, 174.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165484/IMG_20241002_131031_anonimized.jpg: 480x640 1 Automobile, 164.1ms
# Speed: 4.7ms preprocess, 164.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165484/IMG_20241002_131121_anonimized.jpg: 480x640 1 Automobile, 161.0ms
# Speed: 4.8ms preprocess, 161.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165484/IMG_20241002_131136_anonimized.jpg: 480x640 1 Automobile, 257.7ms
# Speed: 6.0ms preprocess, 257.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165484/IMG_20241002_131116_anonimized.jpg: 480x640 1 Automobile, 247.4ms
# Speed: 6.7ms preprocess, 247.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165484/IMG_20241002_131152_1_anonimized.jpg: 480x640 1 Automobile, 164.2ms
# Speed: 4.4ms preprocess, 164.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165484/IMG_20241002_131155_anonimized.jpg: 480x640 1 Automobile, 180.1ms
# Speed: 4.4ms preprocess, 180.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165484/IMG_20241002_131159_anonimized.jpg: 480x640 1 Automobile, 256.4ms
# Speed: 6.1ms preprocess, 256.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165484/IMG_20241002_131207_anonimized.jpg: 640x480 1 Automobile, 251.8ms
# Speed: 6.1ms preprocess, 251.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165484/IMG_20241002_131201_anonimized.jpg: 480x640 1 Automobile, 180.6ms
# Speed: 4.4ms preprocess, 180.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165484/IMG_20241002_131204_anonimized.jpg: 480x640 2 Automobiles, 158.5ms
# Speed: 4.2ms preprocess, 158.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165484/IMG_20241002_131444_anonimized.jpg: 640x480 1 Automobile, 164.1ms
# Speed: 4.5ms preprocess, 164.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165484/IMG_20241002_131449_anonimized.jpg: 480x640 1 Automobile, 163.3ms
# Speed: 4.3ms preprocess, 163.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165484/IMG_20241002_131359_anonimized.jpg: 480x640 1 Automobile, 163.4ms
# Speed: 4.5ms preprocess, 163.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/165484/IMG_20241002_131426_anonimized.jpg: 480x640 1 Automobile, 161.6ms
# Speed: 4.3ms preprocess, 161.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120148_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120148_anonimized.jpg: 480x640 1 Automobile, 161.8ms
# Speed: 4.0ms preprocess, 161.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120156_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120156_anonimized.jpg: 480x640 2 Automobiles, 182.7ms
# Speed: 3.9ms preprocess, 182.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120240_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120240_anonimized.jpg: 480x640 1 Automobile, 162.1ms
# Speed: 4.0ms preprocess, 162.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120200_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120200_anonimized.jpg: 480x640 2 Automobiles, 161.0ms
# Speed: 3.8ms preprocess, 161.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120212_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120212_anonimized.jpg: 480x640 1 Automobile, 161.6ms
# Speed: 3.8ms preprocess, 161.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120220_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120220_anonimized.jpg: 480x640 2 Automobiles, 254.7ms
# Speed: 5.6ms preprocess, 254.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120306_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120306_anonimized.jpg: 640x480 1 Automobile, 166.2ms
# Speed: 3.8ms preprocess, 166.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120336_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120336_anonimized.jpg: 480x640 2 Automobiles, 262.2ms
# Speed: 5.6ms preprocess, 262.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120302_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120302_anonimized.jpg: 640x480 1 Automobile, 270.4ms
# Speed: 9.2ms preprocess, 270.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120331_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120331_anonimized.jpg: 480x640 1 Automobile, 167.4ms
# Speed: 3.9ms preprocess, 167.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120309_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120309_anonimized.jpg: 640x480 1 Automobile, 179.4ms
# Speed: 4.4ms preprocess, 179.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120433_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120433_anonimized.jpg: 480x640 2 Automobiles, 167.7ms
# Speed: 4.0ms preprocess, 167.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120357_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120357_anonimized.jpg: 480x640 1 Automobile, 165.4ms
# Speed: 4.0ms preprocess, 165.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120418_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120418_anonimized.jpg: 480x640 1 Automobile, 182.6ms
# Speed: 3.8ms preprocess, 182.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120526_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120526_anonimized.jpg: 480x640 1 Automobile, 163.8ms
# Speed: 4.0ms preprocess, 163.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120400_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120400_anonimized.jpg: 480x640 1 Automobile, 166.8ms
# Speed: 4.1ms preprocess, 166.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120445_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120445_anonimized.jpg: 480x640 2 Automobiles, 182.9ms
# Speed: 4.1ms preprocess, 182.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120454_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120454_anonimized.jpg: 480x640 1 Automobile, 167.2ms
# Speed: 3.9ms preprocess, 167.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120624_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120624_anonimized.jpg: 480x640 1 Automobile, 256.1ms
# Speed: 5.3ms preprocess, 256.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120508_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120508_anonimized.jpg: 480x640 1 Automobile, 275.1ms
# Speed: 5.5ms preprocess, 275.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120600_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120600_anonimized.jpg: 480x640 1 Automobile, 178.4ms
# Speed: 4.1ms preprocess, 178.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120605_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120605_anonimized.jpg: 480x640 1 Automobile, 169.3ms
# Speed: 4.0ms preprocess, 169.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120541_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120541_anonimized.jpg: 480x640 1 Automobile, 159.3ms
# Speed: 4.3ms preprocess, 159.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120617_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120617_anonimized.jpg: 480x640 1 Automobile, 164.7ms
# Speed: 3.8ms preprocess, 164.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120529_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120529_anonimized.jpg: 480x640 1 Automobile, 177.1ms
# Speed: 3.7ms preprocess, 177.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120638_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120638_anonimized.jpg: 480x640 1 Automobile, 163.1ms
# Speed: 4.2ms preprocess, 163.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120632_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120632_anonimized.jpg: 480x640 1 Automobile, 180.0ms
# Speed: 4.0ms preprocess, 180.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120721_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120721_anonimized.jpg: 480x640 1 Automobile, 274.8ms
# Speed: 8.4ms preprocess, 274.8ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120708_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120708_anonimized.jpg: 480x640 1 Automobile, 301.8ms
# Speed: 6.5ms preprocess, 301.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120734_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120734_anonimized.jpg: 480x640 2 Automobiles, 188.7ms
# Speed: 3.9ms preprocess, 188.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120756_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120756_anonimized.jpg: 480x640 2 Automobiles, 172.1ms
# Speed: 4.3ms preprocess, 172.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120726_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120726_anonimized.jpg: 480x640 1 Automobile, 161.9ms
# Speed: 4.2ms preprocess, 161.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120812_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120812_anonimized.jpg: 480x640 2 Automobiles, 164.9ms
# Speed: 3.8ms preprocess, 164.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120740_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120740_anonimized.jpg: 480x640 1 Automobile, 250.1ms
# Speed: 5.6ms preprocess, 250.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120700_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120700_anonimized.jpg: 480x640 1 Automobile, 188.7ms
# Speed: 4.4ms preprocess, 188.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120852_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120852_anonimized.jpg: 480x640 1 Automobile, 256.3ms
# Speed: 5.5ms preprocess, 256.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120814_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120814_anonimized.jpg: 480x640 1 Automobile, 175.7ms
# Speed: 4.0ms preprocess, 175.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120831_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120831_anonimized.jpg: 480x640 2 Automobiles, 173.4ms
# Speed: 4.3ms preprocess, 173.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120907_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120907_anonimized.jpg: 480x640 1 Automobile, 167.8ms
# Speed: 4.0ms preprocess, 167.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120915_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120915_anonimized.jpg: 480x640 1 Automobile, 173.9ms
# Speed: 4.1ms preprocess, 173.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120839_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120839_anonimized.jpg: 480x640 3 Automobiles, 168.0ms
# Speed: 4.0ms preprocess, 168.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120931_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120931_anonimized.jpg: 480x640 1 Automobile, 168.2ms
# Speed: 4.0ms preprocess, 168.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_121038_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_121038_anonimized.jpg: 480x640 1 Automobile, 166.2ms
# Speed: 3.9ms preprocess, 166.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_121002_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_121002_anonimized.jpg: 480x640 1 Automobile, 169.8ms
# Speed: 4.1ms preprocess, 169.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_121024_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_121024_anonimized.jpg: 480x640 1 Automobile, 168.3ms
# Speed: 4.0ms preprocess, 168.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120910_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120910_anonimized.jpg: 480x640 1 Automobile, 167.1ms
# Speed: 4.1ms preprocess, 167.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_121031_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_121031_anonimized.jpg: 480x640 1 Automobile, 165.0ms
# Speed: 4.1ms preprocess, 165.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120942_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_120942_anonimized.jpg: 480x640 1 Automobile, 186.8ms
# Speed: 4.0ms preprocess, 186.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_121252_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_121252_anonimized.jpg: 480x640 1 Automobile, 256.5ms
# Speed: 5.7ms preprocess, 256.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_121047_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_121047_anonimized.jpg: 480x640 1 Automobile, 175.9ms
# Speed: 3.9ms preprocess, 175.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_121244_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_121244_anonimized.jpg: 480x640 1 Automobile, 168.3ms
# Speed: 4.0ms preprocess, 168.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_121346_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_121346_anonimized.jpg: 480x640 1 Automobile, 168.9ms
# Speed: 3.9ms preprocess, 168.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_121237_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_121237_anonimized.jpg: 480x640 1 Automobile, 190.5ms
# Speed: 4.0ms preprocess, 190.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/159347/20250320_121258_anonimized.jpg
#
# ...
# /content/drive/MyDrive/nlp_project_elte/data/158220/IMG_20240319_142626_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/158220/IMG_20240319_142626_anonimized.jpg: 480x640 1 Automobile, 168.5ms
# Speed: 3.9ms preprocess, 168.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/158220/IMG_20240319_142603_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/158220/IMG_20240319_142603_anonimized.jpg: 480x640 1 Automobile, 162.9ms
# Speed: 4.1ms preprocess, 162.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/158220/IMG_20240319_142621_1_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/158220/IMG_20240319_142621_1_anonimized.jpg: 480x640 1 Automobile, 170.5ms
# Speed: 3.8ms preprocess, 170.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/158220/IMG_20240319_142550_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/158220/IMG_20240319_142550_anonimized.jpg: 480x640 2 Automobiles, 269.3ms
# Speed: 5.3ms preprocess, 269.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/158220/IMG_20240319_142555_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/158220/IMG_20240319_142555_anonimized.jpg: 480x640 1 Automobile, 164.4ms
# Speed: 3.8ms preprocess, 164.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/158220/IMG_20240319_142901_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/158220/IMG_20240319_142901_anonimized.jpg: 480x640 1 Automobile, 167.2ms
# Speed: 3.7ms preprocess, 167.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/158220/IMG_20240319_142722_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/158220/IMG_20240319_142722_anonimized.jpg: 480x640 1 Automobile, 165.0ms
# Speed: 3.6ms preprocess, 165.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/158220/IMG_20240319_142619_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/158220/IMG_20240319_142619_anonimized.jpg: 480x640 1 Automobile, 173.4ms
# Speed: 3.7ms preprocess, 173.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/158220/IMG_20240319_142844_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/158220/IMG_20240319_142844_anonimized.jpg: 480x640 1 Automobile, 261.0ms
# Speed: 5.5ms preprocess, 261.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/158220/IMG_20240319_142728_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/158220/IMG_20240319_142728_anonimized.jpg: 480x640 3 Automobiles, 170.3ms
# Speed: 3.9ms preprocess, 170.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/158220/IMG_20240319_142800_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/158220/IMG_20240319_142800_anonimized.jpg: 480x640 1 Automobile, 166.3ms
# Speed: 3.9ms preprocess, 166.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/158220/IMG_20240319_142924_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/158220/IMG_20240319_142924_anonimized.jpg: 480x640 1 Automobile, 272.6ms
# Speed: 6.1ms preprocess, 272.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/158220/IMG_20240319_142915_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/158220/IMG_20240319_142915_anonimized.jpg: 480x640 1 Automobile, 164.1ms
# Speed: 3.6ms preprocess, 164.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/158220/IMG_20240319_142747_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/158220/IMG_20240319_142747_anonimized.jpg: 480x640 1 Automobile, 177.9ms
# Speed: 3.8ms preprocess, 177.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_133853_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_133853_anonimized.jpg: 640x480 1 Automobile, 169.5ms
# Speed: 5.1ms preprocess, 169.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_133904_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_133904_anonimized.jpg: 640x480 1 Automobile, 166.2ms
# Speed: 4.4ms preprocess, 166.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_134737_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_134737_anonimized.jpg: 480x640 2 Automobiles, 163.0ms
# Speed: 4.4ms preprocess, 163.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_134746_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_134746_anonimized.jpg: 480x640 1 Automobile, 165.1ms
# Speed: 4.6ms preprocess, 165.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_134751_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_134751_anonimized.jpg: 640x480 1 Automobile, 165.4ms
# Speed: 4.4ms preprocess, 165.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_134757_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_134757_anonimized.jpg: 480x640 (no detections), 162.7ms
# Speed: 4.4ms preprocess, 162.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_134753_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_134753_anonimized.jpg: 640x480 1 Automobile, 165.3ms
# Speed: 4.5ms preprocess, 165.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_134803_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_134803_anonimized.jpg: 480x640 1 Automobile, 162.3ms
# Speed: 4.3ms preprocess, 162.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_134806_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_134806_anonimized.jpg: 640x480 1 Automobile, 170.3ms
# Speed: 4.6ms preprocess, 170.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_134810_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_134810_anonimized.jpg: 640x480 (no detections), 181.3ms
# Speed: 4.6ms preprocess, 181.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
# /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_134837_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_134837_anonimized.jpg: 480x640 1 Automobile, 173.2ms
# Speed: 4.4ms preprocess, 173.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_134824_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_134824_anonimized.jpg: 640x480 1 Automobile, 176.6ms
# Speed: 4.4ms preprocess, 176.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_134820_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_134820_anonimized.jpg: 480x640 1 Automobile, 162.5ms
# Speed: 4.4ms preprocess, 162.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_134851_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_134851_anonimized.jpg: 480x640 1 Automobile, 167.1ms
# Speed: 4.5ms preprocess, 167.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_134956_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_134956_anonimized.jpg: 480x640 1 Automobile, 178.0ms
# Speed: 4.4ms preprocess, 178.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_134934_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_134934_anonimized.jpg: 480x640 1 Automobile, 162.1ms
# Speed: 4.3ms preprocess, 162.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_134854_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_134854_anonimized.jpg: 640x480 1 Automobile, 180.1ms
# Speed: 4.5ms preprocess, 180.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_134841_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_134841_anonimized.jpg: 480x640 1 Automobile, 159.6ms
# Speed: 4.5ms preprocess, 159.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_135011_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_135011_anonimized.jpg: 480x640 1 Automobile, 180.7ms
# Speed: 4.5ms preprocess, 180.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_135009_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_135009_anonimized.jpg: 480x640 1 Automobile, 166.4ms
# Speed: 4.6ms preprocess, 166.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_135036_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_135036_anonimized.jpg: 480x640 1 Automobile, 282.2ms
# Speed: 6.3ms preprocess, 282.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_135033_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_135033_anonimized.jpg: 480x640 1 Automobile, 287.9ms
# Speed: 6.0ms preprocess, 287.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_135013_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_135013_anonimized.jpg: 480x640 1 Automobile, 268.0ms
# Speed: 6.3ms preprocess, 268.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_135045_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_135045_anonimized.jpg: 480x640 1 Automobile, 263.1ms
# Speed: 5.8ms preprocess, 263.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_135151_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_135151_anonimized.jpg: 480x640 1 Automobile, 253.9ms
# Speed: 6.5ms preprocess, 253.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_135312_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_135312_anonimized.jpg: 480x640 1 Automobile, 164.6ms
# Speed: 4.5ms preprocess, 164.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_135442_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_135442_anonimized.jpg: 480x640 2 Automobiles, 164.2ms
# Speed: 4.4ms preprocess, 164.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_135339_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_135339_anonimized.jpg: 480x640 1 Automobile, 189.0ms
# Speed: 4.9ms preprocess, 189.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_135433_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_135433_anonimized.jpg: 480x640 5 Automobiles, 168.9ms
# Speed: 4.5ms preprocess, 168.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_135326_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_135326_anonimized.jpg: 480x640 1 Automobile, 164.7ms
# Speed: 4.4ms preprocess, 164.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_135148_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_135148_anonimized.jpg: 480x640 1 Automobile, 170.7ms
# Speed: 4.4ms preprocess, 170.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_135500_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_135500_anonimized.jpg: 480x640 3 Automobiles, 172.5ms
# Speed: 4.3ms preprocess, 172.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_135507_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_135507_anonimized.jpg: 480x640 1 Automobile, 179.9ms
# Speed: 4.2ms preprocess, 179.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_135450_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_135450_anonimized.jpg: 480x640 3 Automobiles, 259.6ms
# Speed: 6.5ms preprocess, 259.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_135759_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_135759_anonimized.jpg: 480x640 1 Automobile, 166.6ms
# Speed: 4.4ms preprocess, 166.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_135753_anonimized.jpg
#
# image 1/1 /content/drive/MyDrive/nlp_project_elte/data/157515_v2/IMG_20240402_135753_anonimized.jpg: 480x640 1 Automobile, 169.8ms
# Speed: 4.4ms preprocess, 169.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)

# %%
import pandas as pd
df = pd.DataFrame(data)

# %%
df.to_csv("/content/drive/MyDrive/nlp_project_elte/data2.csv")
